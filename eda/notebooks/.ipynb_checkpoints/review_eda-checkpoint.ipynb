# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from pathlib import Path

# %%
data_path = Path("../data/p4k_reviews.csv")

review_df = pd.read_csv(data_path)
review_df.head()
# Out:
#              artist                       album         genre          label  \
# 0   Miranda Lambert                    Wildcard  Folk/Country         Vanner
# 1         Skee Mask                      ISS004    Electronic     Ilian Tape
# 2  Michael Kiwanuka                    Kiwanuka       Pop/R&B     Interscope
# 3        Rocketship               Thanks to You          Rock  nonstop co-op
# 4      Van Morrison  Three Chords and the Truth          Rock          Exile
#
#                                               review        date  score
# 0  Miranda Lambert opens  Wildcard with confidenc...  2019-11-01    7.4
# 1  In a fractious dance-music scene, one thing se...  2019-11-01    7.8
# 2  “All I want is to talk to you,” Michael Kiwanu...  2019-11-01    7.5
# 3  Rocketship have long been the type of slightly...  2019-11-01    7.9
# 4  Forty-one albums into his storied career, Van ...  2019-10-31    7.3

# %%
print(f"{review_df.shape[0]} samples in dataset")
# Out:
# 60 samples in dataset

# %%
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 7 columns):
# artist    60 non-null object
# album     60 non-null object
# genre     57 non-null object
# label     60 non-null object
# review    60 non-null object
# date      60 non-null object
# score     60 non-null float64
# dtypes: float64(1), object(6)
# memory usage: 3.4+ KB

# %%
review_df.describe()
# Out:
#           score
# count  60.00000
# mean    7.13500
# std     0.96723
# min     4.00000
# 25%     6.80000
# 50%     7.40000
# 75%     7.72500
# max     9.00000

# %%
fig, ax = plt.subplots(figsize=(7,5))
review_df.plot(ax=ax, x="date", y="score")

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,5))
sns.catplot(ax=axes[0], x="genre", y="score", data=review_df)
sns.violinplot(ax=axes[1], x="genre", y="score", data=review_df)
plt.close(2)
